# %% [markdown]
# <a href="https://colab.research.google.com/github/Josh1313/PRUEBA_VISUALCODE/blob/master/Tuesday_1_nn_mnist_tf2_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Primer ejemplo de Red Neuronal  en este notebook solo lo ejecutaremos de manera sencilla (linear) y haremos un duplicado para poder aplicarle otras tecnicas para que sea mas eficiente

# %% [markdown]
# Recordemos los pasos a seguiren la creación de código para entrenar una red neuronal:
# <ol>
#     <li>Importar librerias: Keras, PyPlot y Numpy (añado time y datetime para controlar los tiempos de entrenamiento)</li>
#     <li>Definamos una red inicial (apilando bloques)</li>
#     <li>Definimos (o creamos) nuestro optimizador, añadiendo nuestra función error</li>
#     <li>Preparamos los datos (en este caso los cargamos)</li>
#     <li>Empezamos con el entrenamiento</li>
#     <li>Miramos los resultados y pasamos a la crítica mordaz</li>
# </ol>

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

# %% [markdown]
# ## 2. Arquitectura de red del modelo
#
# Construimos un modelo sencillo de red neuronal para los datos MNIST, que en resumen son:
# - Datos de entrada: imagenes de 28x28 pixeles con un canal de grises (valores de 0 a 255, enteros)
# - Datos de salida (labels): a cada imagen le otorgamos un valor de 0 a 9, un total de 10 classes
#
# <img src="https://3qeqpr26caki16dnhd19sv6by6v-wpengine.netdna-ssl.com/wp-content/uploads/2016/05/Examples-from-the-MNIST-dataset.png">
#
# Para montar la arquitectura de la red neuronal se sigue el método **.Sequential()** de Keras (de input a output):
#
# - **Entrada** - Una conversion de una matriz 2D de 28x28 pixeles a un vector - método Flatten
# - **Oculto** - Una capa densa (fully connected) con 16 neuronas y activación lineal
# - **Salida** - Una capa densa (fully connected) con 10 neuronas (**las 10 clases de salida**) y activación softmax
#
# <img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/11/Colored_neural_network_es.svg/300px-Colored_neural_network_es.svg.png" decoding="async" width="300" height="361" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/11/Colored_neural_network_es.svg/450px-Colored_neural_network_es.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/11/Colored_neural_network_es.svg/600px-Colored_neural_network_es.svg.png 2x" data-file-width="296" data-file-height="356">

# %% [markdown]
#  Dos funciones que no se puden mover porque se arruinara el proceso 1 cualquier red neuronal 2 capas inamovible porque vienen definidas por los datos capa de entrada y cual es el shape la entrada es de 28x28 y la de salida tambien 10 osea la salida no MOVER

# %%
model = ks.Sequential()

model.add(ks.layers.Flatten(input_shape=(28, 28)))# Esto
model.add(ks.layers.Dense(32, activation='linear'))# le ponemos esta capa mas para que el modelo mejore, pero en realidad no mejora porque ya aprendieron lo que tenia que aprender
model.add(ks.layers.Dense(16, activation='linear'))
model.add(ks.layers.Dense(10, activation='softmax'))# esto

# %% [markdown]
#  Para en el siguiente ejemplo2 pondremos una funcion no lineal para que mejore el modelo que es la Relu

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_5 (Dense)             (None, 32)                25120
#
#  dense_6 (Dense)             (None, 16)                528
#
#  dense_7 (Dense)             (None, 10)                170
#
# =================================================================
# Total params: 25,818
# Trainable params: 25,818
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %% [markdown]
# tDel **.summary()** se extrae información muy relevante: el número de paràmetros por capa y el total a entrenar.4
#
# Fijaos que 28x28 son 784 valores, así que es lo que tenemos de entrada. Esos 784 neuronas se enlazan con 16 (16 * 784 pesos + 16 bias = 12560) y esas 16 con las 10 de salida (16 * 10 pesos + 10 bias). Un total de 12730 parametros que aprender

# %% [markdown]
# ## 3. Optimizador, función error
#
# Definimos los parametros del modelo para su entrenamiento:
# * **Loss** - Función de error (función de coste) - Optamos por la Sparse Categorical Crosstentropy porque estamos clasificando imagenes
# * **Optimizer** - que optimizador de la función de coste usaremos, en este ejemplo SGD (Stochastic gradient descent)
# * **Metrics** - que metrica usaremos para evaluar el modelo... en este caso se usa la Accuracy
#
# **Nota sobre SGD:** por defecto lleva un learning rate de 0.01 y sin momentum (valor de 0.0)

# %%
model.compile(optimizer='SGD',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'], )

# %%
# Loss se utilizara por ser multiclase y entrenaremos accuracy

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de MNIST de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
mnist = ks.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset MNIST, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):
    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))

plt.subplots_adjust(hspace = 0.5)
plt.show()
# Out:
# Train: X=(60000, 28, 28), y=(60000,)
# Test: X=(10000, 28, 28), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %%
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Val: X=%s, y=%s' % (x_val.shape, y_val.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
# Out:
# Train: X=(50000, 28, 28), y=(50000,)
# Val: X=(10000, 28, 28), y=(10000,)
# Test: X=(10000, 28, 28), y=(10000,)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!!
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), por defecto en Keras, **el batch_size es de 32**.
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.
#
# **Nota: Este fit, en mi laptop no tarda más de 2 minutos.** (por eso vale la pena capturar los tiempos, así podeis validar las capacidades de vuestro equipo y valorar Google Colab).

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train, y_train,
    batch_size=32,
    epochs=30,
    validation_data=(x_val, y_val))
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - 6s 3ms/step - loss: 0.6695 - accuracy: 0.8129 - val_loss: 0.3558 - val_accuracy: 0.8996
# Epoch 2/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.3622 - accuracy: 0.8978 - val_loss: 0.3114 - val_accuracy: 0.9118
# Epoch 3/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.3277 - accuracy: 0.9071 - val_loss: 0.2953 - val_accuracy: 0.9163
# Epoch 4/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.3121 - accuracy: 0.9115 - val_loss: 0.2858 - val_accuracy: 0.9191
# Epoch 5/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.3023 - accuracy: 0.9143 - val_loss: 0.2795 - val_accuracy: 0.9222
# Epoch 6/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2957 - accuracy: 0.9164 - val_loss: 0.2768 - val_accuracy: 0.9215
# Epoch 7/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2905 - accuracy: 0.9182 - val_loss: 0.2750 - val_accuracy: 0.9240
# Epoch 8/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2860 - accuracy: 0.9197 - val_loss: 0.2713 - val_accuracy: 0.9239
# Epoch 9/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2827 - accuracy: 0.9201 - val_loss: 0.2710 - val_accuracy: 0.9255
# Epoch 10/30
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.2793 - accuracy: 0.9216 - val_loss: 0.2719 - val_accuracy: 0.9246
# Epoch 11/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2772 - accuracy: 0.9223 - val_loss: 0.2671 - val_accuracy: 0.9275
# Epoch 12/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2748 - accuracy: 0.9223 - val_loss: 0.2663 - val_accuracy: 0.9264
# Epoch 13/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2728 - accuracy: 0.9238 - val_loss: 0.2676 - val_accuracy: 0.9261
# Epoch 14/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2714 - accuracy: 0.9241 - val_loss: 0.2641 - val_accuracy: 0.9272
# Epoch 15/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2698 - accuracy: 0.9246 - val_loss: 0.2653 - val_accuracy: 0.9273
# Epoch 16/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2679 - accuracy: 0.9255 - val_loss: 0.2664 - val_accuracy: 0.9269
# Epoch 17/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2667 - accuracy: 0.9249 - val_loss: 0.2645 - val_accuracy: 0.9276
# Epoch 18/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2655 - accuracy: 0.9266 - val_loss: 0.2652 - val_accuracy: 0.9273
# Epoch 19/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2646 - accuracy: 0.9258 - val_loss: 0.2644 - val_accuracy: 0.9265
# Epoch 20/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2632 - accuracy: 0.9262 - val_loss: 0.2627 - val_accuracy: 0.9285
# Epoch 21/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2619 - accuracy: 0.9263 - val_loss: 0.2590 - val_accuracy: 0.9304
# Epoch 22/30
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.2611 - accuracy: 0.9271 - val_loss: 0.2619 - val_accuracy: 0.9286
# Epoch 23/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2604 - accuracy: 0.9274 - val_loss: 0.2612 - val_accuracy: 0.9282
# Epoch 24/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2595 - accuracy: 0.9282 - val_loss: 0.2588 - val_accuracy: 0.9286
# Epoch 25/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2588 - accuracy: 0.9273 - val_loss: 0.2628 - val_accuracy: 0.9285
# Epoch 26/30
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.2581 - accuracy: 0.9280 - val_loss: 0.2601 - val_accuracy: 0.9308
# Epoch 27/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2577 - accuracy: 0.9276 - val_loss: 0.2615 - val_accuracy: 0.9292
# Epoch 28/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2560 - accuracy: 0.9289 - val_loss: 0.2611 - val_accuracy: 0.9296
# Epoch 29/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2562 - accuracy: 0.9284 - val_loss: 0.2628 - val_accuracy: 0.9290
# Epoch 30/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2550 - accuracy: 0.9286 - val_loss: 0.2670 - val_accuracy: 0.9264

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:02:22.801364

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='validation')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='validation')
plt.legend()
plt.show()

# %% [markdown]
# Evaluemos el modelo contra los valores de testeo

# %%
model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.2754 - accuracy: 0.9239 - 662ms/epoch - 2ms/step
# [0.2754177451133728, 0.9239000082015991]

# %% [markdown]
# El coste podemos ver que es estable. Además la accuracy baila muchísimo. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos los primeros digitos, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo

# %%
num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()

# %% [markdown]
#  Un aletorio en el batch y en los pesos por mucho que queramos no podremos tener el mismo entrenamiento es imposible

# %% [markdown]
# # A continuacion se pone el metodo para guardar el modelo

# %%
#from tensorflow.keras.models import load_model

#model.save('mnist_model.h5')
